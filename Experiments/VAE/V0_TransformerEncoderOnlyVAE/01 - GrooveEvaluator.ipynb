# %%
import wandb
import os
os.environ["WANDB_SILENT"] = "true"

import numpy as np
import pandas as pd

import sys
sys.path.insert(0, "../../..")

os.chdir("../../..")
project_root = os.getcwd()

from helpers import load_variational_mgt_model
from model import GrooveTransformerEncoderVAE
import torch

from umap import UMAP

from bokeh.palettes import inferno, Category20b
from bokeh.core.enums import MarkerType
from bokeh.plotting import figure, show, save
from bokeh.io import output_notebook
output_notebook()
# Out:
# Holoviews not installed, will not be able to generate violin plots
# WARNING:data.Base.utils:Holoviews not installed. Please install holoviews to be able to generate heatmaps.
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Load Test Set and Create a GrooveEvaluator Instance

# %%
from data import load_gmd_hvo_sequences

dataset_setting_json_path = "data/dataset_json_settings/4_4_Beats_gmd.json"
test_set = load_gmd_hvo_sequences(dataset_setting_json_path, "test")
# Out:
# INFO:data.Base.dataLoaders:Loading gmd dataset
# INFO:data.Base.dataLoaders:Loading Cached Version from: data/gmd/resources/cached/beat_division_factor_[4]/drum_mapping_label_ROLAND_REDUCED_MAPPING/beat_type_['beat']_time_signature_['4-4']
# /home/dtic/Github/GrooveTransformer

# %% [markdown]
# #### 1. Run `00 - DownloadFromWandB.py` to download model artifacts
#
# #### 2. Load the `downloaded_artifacts.json` file for the paths to locally available artifacts

# %%
import json

project_root = os.getcwd()
with open("Experiments/VAE/V0_TransformerEncoderOnlyVAE/downloaded_artifacts.json", "rb") as f:
    downloaded_models = json.load(f)

print(json.dumps(downloaded_models, sort_keys=True, indent=1))
# Out:
# {
#  "GOOD_AVERAGE_glamorous-sweep-62_epoch_100": {
#   "artifact_name": "model_epoch_100:v283",
#   "epoch": "100",
#   "load_path": "./artifacts/model_epoch_100:v283/100.pth",
#   "wandb_link": "mmil_vae_g2d/voice_distribution_and_genre_distribution_imbalance/model_epoch_100:v283"
#  },
#  "GOOD_apricot-sweep-17_epoch_100": {
#   "artifact_name": "model_epoch_100:v242",
#   "epoch": "100",
#   "load_path": "./artifacts/model_epoch_100:v242/100.pth",
#   "wandb_link": "mmil_vae_g2d/voice_distribution_and_genre_distribution_imbalance/model_epoch_100:v242"
#  },
#  "GOOD_azure-sweep-54_epoch_100": {
#   "artifact_name": "model_epoch_100:v279",
#   "epoch": "100",
#   "load_path": "./artifacts/model_epoch_100:v279/100.pth",
#   "wandb_link": "mmil_vae_g2d/voice_distribution_and_genre_distribution_imbalance/model_epoch_100:v279"
#  },
#  "GOOD_hearty-sweep-60_epoch_100": {
#   "artifact_name": "model_epoch_100:v280",
#   "epoch": "100",
# ...

# %% [markdown]
# #### 3. Select a specific Run and load the model

# %%
run_name = "noble-field-7_epoch_100"
model = load_variational_mgt_model(f"Experiments/VAE/V0_TransformerEncoderOnlyVAE/{downloaded_models[run_name]['load_path']}")
# Out:
# Offset activation is sigmoid, bias is initialized to 0.5

# %%
os.rename(artifact_dir.)
